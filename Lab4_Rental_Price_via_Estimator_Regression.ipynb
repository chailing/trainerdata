# %% [markdown]
# # Lab - Rental Price
# Reference: Dataset was extracted from one of the popular property listing site (updated to Sep 2018)
#
# Exercise:
# 1. Try train on all states dataset, then predict the rental based on selected features
# 2. Try train on only Selangor dataset, then predict the rental based on selected features

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import shutil

# %% [markdown]
# ## Read dataset

# %%
df_orig = pd.read_csv("https://raw.githubusercontent.com/thenghui/trainerdata/master/RentIndexRaw.csv", low_memory=False)
COLUMNS = list(df_orig)
print (COLUMNS)
# Out:
# ['ID', 'BuiltUpSize', 'City', 'CreatedDateTime', 'CreatedUser', 'DataSourceID', 'Furnishing', 'Latitude', 'Longitude', 'NoOfBathroom', 'NoOfBedroom', 'NoOfParking', 'Postcode', 'PostedDate', 'PropertyAddress', 'PropertyName', 'PropertyType', 'RentalPerMth', 'SourceUrl', 'State', 'UpdatedDateTime', 'UpdatedUser']

# %% [markdown]
# ## Preparing dataset

# %%
print('Original dataset: {}'.format(df_orig.shape))

df_orig['State'] = df_orig['State'].str.upper()
df_orig['City'] = df_orig['City'].str.upper()
df_orig['PropertyType'] = df_orig['PropertyType'].str.upper()

# Selangor
df_sel = df_orig[(df_orig.State == 'SELANGOR')]
print('Selangor dataset: {}'.format(df_sel.shape))

# KL
df_kul = df_orig[(df_orig.State == 'KUALA-LUMPUR')]
print('KL dataset: {}'.format(df_kul.shape))

# Use Selangor data
# remove rows with zero value
df = df_sel[(df_sel[['BuiltUpSize','RentalPerMth', 'NoOfBedroom']] != 0).all(axis=1)]
                            #'NoOfBathroom', 'NoOfParking']] != 0).all(axis=1)]


print('Wanted dataset: {}'.format(df.shape))
# Out:
# Original dataset: (54405, 22)
# Selangor dataset: (30292, 22)
# KL dataset: (13648, 22)
# Wanted dataset: (20626, 22)

# %% [markdown]
# ## Split into dataset of: Train, Validation, Test (70%-20%-10%)

# %%
df_train0, df_valid0, df_test0 = np.split(df.sample(frac=1), [int(.7*len(df)), int(.9*len(df))])

# Retrieve only Featured columns
df_train = df_train0[['State','BuiltUpSize','RentalPerMth','NoOfBedroom','Furnishing','PropertyType']]
df_valid = df_valid0[['State','BuiltUpSize','RentalPerMth','NoOfBedroom','Furnishing','PropertyType']]
df_test = df_test0[['State','BuiltUpSize','RentalPerMth','NoOfBedroom','Furnishing','PropertyType']]

print('Train: {}'.format(df_train.shape))
print('Valid: {}'.format(df_valid.shape))
print('Test: {}'.format(df_test.shape))
# Out:
# Train: (14438, 6)
# Valid: (4125, 6)
# Test: (2063, 6)

# %% [markdown]
# ## Categorize string value columns

# %%
df_train['PropertyType'].unique()
# Out:
# array(['CONDOMINIUM', 'SERVICED RESIDENCE', 'TOWNHOUSE', 'FLAT',
#        '2-STY TERRACE/LINK HOUSE', '1-STY TERRACE/LINK HOUSE',
#        '2.5-STY TERRACE/LINK HOUSE', 'APARTMENT',
#        '3-STY TERRACE/LINK HOUSE', 'SEMI-DETACHED HOUSE', 'BUNGALOW',
#        '1.5-STY TERRACE/LINK HOUSE', 'CLUSTER HOUSE',
#        '4-STY TERRACE/LINK HOUSE', '3.5-STY TERRACE/LINK HOUSE'],
#       dtype=object)

# %%
df_train['State'].unique()
# Out:
# array(['SELANGOR'], dtype=object)

# %% [markdown]
# ## Determine metrics for validation - RMSE

# %%
def print_rmse(model, df):
  metrics = model.evaluate(input_fn = tf.estimator.inputs.pandas_input_fn(
    x = df,
    y = df[LABEL],
    batch_size = 128,
    shuffle = False,
    #queue_capacity = 100
      
  ))
  print('RMSE on dataset = {}'.format(np.sqrt(metrics['average_loss'])))
    
#print_rmse(model, df_valid)

# %% [markdown]
# ## Model: DNNRegressor

# %%
# DNNRegressor

LABEL = 'RentalPerMth'
OUTDIR = 'rentalDNNRegression_trained'
tf.logging.set_verbosity(tf.logging.INFO)
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time

# Categorize string features
categorical_column1 = tf.feature_column.categorical_column_with_vocabulary_list(
    key="State", vocabulary_list=['SELANGOR', 'JOHOR', 'KUALA-LUMPUR', 'PUTRAJAYA'], 
    default_value=0)

categorical_column2 = tf.feature_column.categorical_column_with_vocabulary_list(
    key="Furnishing", vocabulary_list=['Unfurnished', 'Fully Furnished', 'Partly Furnished', 'Unknown'], 
    default_value=0)

categorical_column3 = tf.feature_column.categorical_column_with_vocabulary_list(
    key="PropertyType", vocabulary_list=['CONDOMINIUM', 'SERVICED RESIDENCE', 'APARTMENT',
       '2-STY TERRACE/LINK HOUSE', '3-STY TERRACE/LINK HOUSE',
       '1-STY TERRACE/LINK HOUSE', 'TOWNHOUSE', 'SEMI-DETACHED HOUSE',
       'BUNGALOW', '1.5-STY TERRACE/LINK HOUSE',
       '3.5-STY TERRACE/LINK HOUSE', 'CLUSTER HOUSE', 'FLAT',
       '2.5-STY TERRACE/LINK HOUSE', '4-STY TERRACE/LINK HOUSE',
       'RESIDENTIAL LAND'], 
    default_value=0)


model = tf.estimator.DNNRegressor(    
    hidden_units = [32, 512, 128],
    feature_columns = [tf.feature_column.numeric_column('BuiltUpSize'),
                       tf.feature_column.numeric_column('NoOfBedroom'),
                       #tf.feature_column.indicator_column(categorical_column1),
                       tf.feature_column.indicator_column(categorical_column2),
                       tf.feature_column.indicator_column(categorical_column3)
                      ], 
    activation_fn = tf.nn.relu,
  optimizer=tf.train.AdamOptimizer(
        learning_rate=0.001,
        #l1_regularization_strength=0.01
    ),

    model_dir = OUTDIR
)
 

model.train(input_fn = tf.estimator.inputs.pandas_input_fn(
    x = df_train,
    y = df_train[LABEL],
    batch_size = 512,
    num_epochs = 5,
    shuffle = True,
  )
  );

print_rmse(model, df_valid)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'rentalDNNRegression_trained', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f97204c1e80>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into rentalDNNRegression_trained/model.ckpt.
# INFO:tensorflow:loss = 2607808500.0, step = 1
# INFO:tensorflow:global_step/sec: 123.607
# INFO:tensorflow:loss = 405276720000.0, step = 101 (0.811 sec)
# INFO:tensorflow:Saving checkpoints for 141 into rentalDNNRegression_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 516635740.0.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-07-14T08:32:54Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rentalDNNRegression_trained/model.ckpt-141
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-07-14-08:32:55
# INFO:tensorflow:Saving dict for global step 141: average_loss = 229947360.0, global_step = 141, label/mean = 2404.84, loss = 28743420000.0, prediction/mean = 2034.6346
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 141: rentalDNNRegression_trained/model.ckpt-141
# RMSE on dataset = 15164.015625

# %% [markdown]
# ## Prediction

# %%
predictions = model.predict(input_fn = tf.estimator.inputs.pandas_input_fn(
#    x = pd.DataFrame({
#                      'BuiltUpSize':[560,1200,1600],
#                      'NoOfBedroom':[2,3,3],
#                      'PropertyType':['CONDOMINIUM', 'SERVICED RESIDENCE', 'APARTMENT'],
#                      'Furnishing':['Unfurnished', 'Fully Furnished', 'Partly Furnished']}),
    x = df_test,
    y = None,
    batch_size = 128,
    shuffle = False
  ))

for items in predictions:
  print(items)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rentalDNNRegression_trained/model.ckpt-564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# {'predictions': array([1381.7448], dtype=float32)}
# {'predictions': array([947.01685], dtype=float32)}
# {'predictions': array([1854.8107], dtype=float32)}
# {'predictions': array([1636.5519], dtype=float32)}
# {'predictions': array([947.01685], dtype=float32)}
# {'predictions': array([2509.756], dtype=float32)}
# {'predictions': array([2072.5413], dtype=float32)}
# {'predictions': array([2104.7896], dtype=float32)}
# {'predictions': array([1432.1954], dtype=float32)}
# {'predictions': array([3570.908], dtype=float32)}
# {'predictions': array([933.56335], dtype=float32)}
# {'predictions': array([932.8098], dtype=float32)}
# {'predictions': array([4007.3381], dtype=float32)}
# {'predictions': array([1314.4769], dtype=float32)}
# {'predictions': array([1615.416], dtype=float32)}
# {'predictions': array([932.3136], dtype=float32)}
# {'predictions': array([2032.5604], dtype=float32)}
# {'predictions': array([1212.267], dtype=float32)}
# {'predictions': array([2173.739], dtype=float32)}
# {'predictions': array([910.45166], dtype=float32)}
# {'predictions': array([1847.49], dtype=float32)}
# {'predictions': array([1429.6633], dtype=float32)}
# {'predictions': array([1715.0681], dtype=float32)}
# {'predictions': array([3703.762], dtype=float32)}
# {'predictions': array([1966.8904], dtype=float32)}
# {'predictions': array([1859.2618], dtype=float32)}
# {'predictions': array([3944.2441], dtype=float32)}
# {'predictions': array([2557.1653], dtype=float32)}
# {'predictions': array([3915.1978], dtype=float32)}
# {'predictions': array([2526.1414], dtype=float32)}
# {'predictions': array([2365.452], dtype=float32)}
# {'predictions': array([1715.0681], dtype=float32)}
# {'predictions': array([792.30096], dtype=float32)}
# {'predictions': array([1657.1627], dtype=float32)}
# {'predictions': array([1187.0415], dtype=float32)}
# {'predictions': array([1436.4303], dtype=float32)}
# {'predictions': array([1771.0472], dtype=float32)}
# {'predictions': array([930.7499], dtype=float32)}
# {'predictions': array([1916.118], dtype=float32)}
# {'predictions': array([1619.682], dtype=float32)}
# {'predictions': array([983.9885], dtype=float32)}
# {'predictions': array([1034.465], dtype=float32)}
# {'predictions': array([1060.9144], dtype=float32)}
# {'predictions': array([3817.0327], dtype=float32)}
# {'predictions': array([3879.4475], dtype=float32)}
# {'predictions': array([1760.4738], dtype=float32)}
# {'predictions': array([1656.705], dtype=float32)}
# {'predictions': array([1748.82], dtype=float32)}
# {'predictions': array([1365.7991], dtype=float32)}
# {'predictions': array([1195.1285], dtype=float32)}
# {'predictions': array([1439.2957], dtype=float32)}
# {'predictions': array([3617.1853], dtype=float32)}
# {'predictions': array([1443.5874], dtype=float32)}
# {'predictions': array([1982.954], dtype=float32)}
# {'predictions': array([2184.7317], dtype=float32)}
# {'predictions': array([1074.8257], dtype=float32)}
# {'predictions': array([1044.0975], dtype=float32)}
# {'predictions': array([2196.5293], dtype=float32)}
# {'predictions': array([1635.7325], dtype=float32)}
# {'predictions': array([1098.1212], dtype=float32)}
# {'predictions': array([1839.5135], dtype=float32)}
# {'predictions': array([1152.1836], dtype=float32)}
# {'predictions': array([1648.7543], dtype=float32)}
# {'predictions': array([1802.0842], dtype=float32)}
# {'predictions': array([938.58276], dtype=float32)}
# {'predictions': array([1205.5145], dtype=float32)}
# {'predictions': array([944.08545], dtype=float32)}
# {'predictions': array([1605.7578], dtype=float32)}
# {'predictions': array([2026.2997], dtype=float32)}
# {'predictions': array([1599.4886], dtype=float32)}
# {'predictions': array([1926.2081], dtype=float32)}
# {'predictions': array([1473.8322], dtype=float32)}
# {'predictions': array([1432.1954], dtype=float32)}
# {'predictions': array([766.61786], dtype=float32)}
# {'predictions': array([2003.8877], dtype=float32)}
# {'predictions': array([1017.648], dtype=float32)}
# {'predictions': array([1692.7739], dtype=float32)}
# {'predictions': array([1800.8601], dtype=float32)}
# {'predictions': array([901.6111], dtype=float32)}
# {'predictions': array([1692.7739], dtype=float32)}
# {'predictions': array([1583.5481], dtype=float32)}
# {'predictions': array([1851.4501], dtype=float32)}
# {'predictions': array([2526.5762], dtype=float32)}
# {'predictions': array([3368.2947], dtype=float32)}
# {'predictions': array([2317.611], dtype=float32)}
# {'predictions': array([1922.4128], dtype=float32)}
# {'predictions': array([1222.7892], dtype=float32)}
# {'predictions': array([765.3938], dtype=float32)}
# {'predictions': array([1724.7262], dtype=float32)}
# {'predictions': array([1921.1632], dtype=float32)}
# {'predictions': array([1219.8396], dtype=float32)}
# {'predictions': array([2036.7682], dtype=float32)}
# {'predictions': array([846.54724], dtype=float32)}
# {'predictions': array([1446.4546], dtype=float32)}
# {'predictions': array([1541.5056], dtype=float32)}
# {'predictions': array([2150.6272], dtype=float32)}
# {'predictions': array([1961.5237], dtype=float32)}
# {'predictions': array([890.685], dtype=float32)}
# {'predictions': array([1963.9589], dtype=float32)}
# {'predictions': array([2960.7463], dtype=float32)}
# {'predictions': array([1656.6664], dtype=float32)}
# {'predictions': array([2000.2028], dtype=float32)}
# {'predictions': array([2509.756], dtype=float32)}
# {'predictions': array([1285.0375], dtype=float32)}
# {'predictions': array([1253.5559], dtype=float32)}
# {'predictions': array([1242.2161], dtype=float32)}
# {'predictions': array([2778.8303], dtype=float32)}
# {'predictions': array([1332.0994], dtype=float32)}
# {'predictions': array([1652.8453], dtype=float32)}
# {'predictions': array([1725.6545], dtype=float32)}
# {'predictions': array([1432.1954], dtype=float32)}
# {'predictions': array([1739.9456], dtype=float32)}
# {'predictions': array([1464.1477], dtype=float32)}
# {'predictions': array([1111.0695], dtype=float32)}
# {'predictions': array([815.84467], dtype=float32)}
# {'predictions': array([1603.7804], dtype=float32)}
# {'predictions': array([3367.423], dtype=float32)}
# {'predictions': array([2172.9724], dtype=float32)}
# {'predictions': array([1287.5698], dtype=float32)}
# {'predictions': array([1776.8588], dtype=float32)}
# {'predictions': array([1570.0103], dtype=float32)}
# {'predictions': array([2815.8247], dtype=float32)}
# {'predictions': array([1225.7206], dtype=float32)}
# {'predictions': array([2026.2997], dtype=float32)}
# {'predictions': array([4037.512], dtype=float32)}
# {'predictions': array([2026.2997], dtype=float32)}
# {'predictions': array([1690.714], dtype=float32)}
# {'predictions': array([1930.7955], dtype=float32)}
# {'predictions': array([1509.1477], dtype=float32)}
# {'predictions': array([1436.3644], dtype=float32)}
# {'predictions': array([1436.835], dtype=float32)}
# {'predictions': array([1095.504], dtype=float32)}
# {'predictions': array([1366.6095], dtype=float32)}
# {'predictions': array([1660.0298], dtype=float32)}
# {'predictions': array([1712.2008], dtype=float32)}
# {'predictions': array([2060.744], dtype=float32)}
# {'predictions': array([1444.7727], dtype=float32)}
# {'predictions': array([1826.8065], dtype=float32)}
# {'predictions': array([2597.9966], dtype=float32)}
# {'predictions': array([1963.6193], dtype=float32)}
# {'predictions': array([1218.9938], dtype=float32)}
# {'predictions': array([1927.458], dtype=float32)}
# {'predictions': array([1026.0565], dtype=float32)}
# {'predictions': array([1725.1582], dtype=float32)}
# {'predictions': array([1657.9161], dtype=float32)}
# {'predictions': array([1040.4384], dtype=float32)}
# {'predictions': array([1186.2882], dtype=float32)}
# {'predictions': array([2177.1023], dtype=float32)}
# {'predictions': array([2370.1755], dtype=float32)}
# {'predictions': array([1493.2023], dtype=float32)}
# {'predictions': array([1939.2299], dtype=float32)}
# {'predictions': array([1692.0205], dtype=float32)}
# {'predictions': array([1624.2821], dtype=float32)}
# {'predictions': array([1924.5265], dtype=float32)}
# {'predictions': array([1352.7502], dtype=float32)}
# {'predictions': array([1607.9359], dtype=float32)}
# {'predictions': array([1189.1553], dtype=float32)}
# {'predictions': array([1336.391], dtype=float32)}
# {'predictions': array([4716.2817], dtype=float32)}
# {'predictions': array([1111.0695], dtype=float32)}
# {'predictions': array([2359.278], dtype=float32)}
# {'predictions': array([3399.3752], dtype=float32)}
# {'predictions': array([1597.8728], dtype=float32)}
# {'predictions': array([1630.6875], dtype=float32)}
# {'predictions': array([1412.8207], dtype=float32)}
# {'predictions': array([2319.2927], dtype=float32)}
# {'predictions': array([930.7499], dtype=float32)}
# {'predictions': array([1434.4598], dtype=float32)}
# {'predictions': array([2781.1091], dtype=float32)}
# {'predictions': array([2003.8877], dtype=float32)}
# {'predictions': array([1687.381], dtype=float32)}
# {'predictions': array([1856.0345], dtype=float32)}
# {'predictions': array([1108.1381], dtype=float32)}
# {'predictions': array([1691.5499], dtype=float32)}
# {'predictions': array([1663.4318], dtype=float32)}
# {'predictions': array([1520.9454], dtype=float32)}
# {'predictions': array([1689.0891], dtype=float32)}
# {'predictions': array([2399.5178], dtype=float32)}
# {'predictions': array([1821.9166], dtype=float32)}
# {'predictions': array([1041.1661], dtype=float32)}
# {'predictions': array([2230.163], dtype=float32)}
# {'predictions': array([1449.0126], dtype=float32)}
# {'predictions': array([1441.4094], dtype=float32)}
# {'predictions': array([1673.9796], dtype=float32)}
# {'predictions': array([1943.8966], dtype=float32)}
# {'predictions': array([2521.0962], dtype=float32)}
# {'predictions': array([1847.49], dtype=float32)}
# {'predictions': array([1437.3184], dtype=float32)}
# {'predictions': array([4047.1462], dtype=float32)}
# {'predictions': array([2197.7532], dtype=float32)}
# {'predictions': array([2297.431], dtype=float32)}
# {'predictions': array([1963.9589], dtype=float32)}
# {'predictions': array([1462.8395], dtype=float32)}
# {'predictions': array([1037.507], dtype=float32)}
# {'predictions': array([6146.0747], dtype=float32)}
# {'predictions': array([765.3938], dtype=float32)}
# {'predictions': array([3050.8298], dtype=float32)}
# {'predictions': array([898.6797], dtype=float32)}
# {'predictions': array([2214.5315], dtype=float32)}
# {'predictions': array([1488.6149], dtype=float32)}
# {'predictions': array([1509.5487], dtype=float32)}
# {'predictions': array([2521.8496], dtype=float32)}
# {'predictions': array([1462.466], dtype=float32)}
# {'predictions': array([1625.1847], dtype=float32)}
# {'predictions': array([1710.4806], dtype=float32)}
# {'predictions': array([1546.4664], dtype=float32)}
# {'predictions': array([1988.434], dtype=float32)}
# {'predictions': array([1857.2587], dtype=float32)}
# {'predictions': array([1318.6458], dtype=float32)}
# {'predictions': array([915.9929], dtype=float32)}
# {'predictions': array([2028.3596], dtype=float32)}
# {'predictions': array([1101.7328], dtype=float32)}
# {'predictions': array([1557.4464], dtype=float32)}
# {'predictions': array([2173.739], dtype=float32)}
# {'predictions': array([2317.611], dtype=float32)}
# {'predictions': array([1503.6322], dtype=float32)}
# {'predictions': array([1433.0668], dtype=float32)}
# {'predictions': array([2542.462], dtype=float32)}
# {'predictions': array([2123.8472], dtype=float32)}
# {'predictions': array([1320.353], dtype=float32)}
# {'predictions': array([3033.5557], dtype=float32)}
# {'predictions': array([1536.0807], dtype=float32)}
# {'predictions': array([1205.5145], dtype=float32)}
# {'predictions': array([184.59673], dtype=float32)}
# {'predictions': array([1516.2804], dtype=float32)}
# {'predictions': array([1436.3644], dtype=float32)}
# {'predictions': array([2357.8196], dtype=float32)}
# {'predictions': array([1800.8601], dtype=float32)}
# {'predictions': array([3834.9338], dtype=float32)}
# {'predictions': array([2008.1793], dtype=float32)}
# {'predictions': array([1487.2858], dtype=float32)}
# {'predictions': array([1572.6476], dtype=float32)}
# {'predictions': array([1280.411], dtype=float32)}
# {'predictions': array([944.08545], dtype=float32)}
# {'predictions': array([2086.2908], dtype=float32)}
# {'predictions': array([1800.8601], dtype=float32)}
# {'predictions': array([2028.3596], dtype=float32)}
# {'predictions': array([1635.7325], dtype=float32)}
# {'predictions': array([1324.567], dtype=float32)}
# {'predictions': array([1880.8024], dtype=float32)}
# {'predictions': array([1160.592], dtype=float32)}
# {'predictions': array([1320.353], dtype=float32)}
# {'predictions': array([2358.4065], dtype=float32)}
# {'predictions': array([1963.6888], dtype=float32)}
# {'predictions': array([8290.374], dtype=float32)}
# {'predictions': array([1675.2036], dtype=float32)}
# {'predictions': array([1546.145], dtype=float32)}
# {'predictions': array([2060.7173], dtype=float32)}
# {'predictions': array([2104.8816], dtype=float32)}
# {'predictions': array([2344.0222], dtype=float32)}
# {'predictions': array([3802.9817], dtype=float32)}
# {'predictions': array([3802.9817], dtype=float32)}
# {'predictions': array([1727.284], dtype=float32)}
# {'predictions': array([1320.353], dtype=float32)}
# {'predictions': array([1448.9281], dtype=float32)}
# {'predictions': array([765.3938], dtype=float32)}
# {'predictions': array([2196.5293], dtype=float32)}
# {'predictions': array([1860.1901], dtype=float32)}
# {'predictions': array([2862.915], dtype=float32)}
# {'predictions': array([2025.4281], dtype=float32)}
# {'predictions': array([1519.2118], dtype=float32)}
# {'predictions': array([1851.2854], dtype=float32)}
# {'predictions': array([1919.0494], dtype=float32)}
# {'predictions': array([1857.2587], dtype=float32)}
# {'predictions': array([5359.4043], dtype=float32)}
# {'predictions': array([3399.3752], dtype=float32)}
# {'predictions': array([1130.3217], dtype=float32)}
# {'predictions': array([1662.9612], dtype=float32)}
# {'predictions': array([2364.6985], dtype=float32)}
# {'predictions': array([2175.395], dtype=float32)}
# {'predictions': array([1672.2721], dtype=float32)}
# {'predictions': array([1060.9144], dtype=float32)}
# {'predictions': array([848.72516], dtype=float32)}
# {'predictions': array([3871.9314], dtype=float32)}
# {'predictions': array([2597.2043], dtype=float32)}
# {'predictions': array([1822.2645], dtype=float32)}
# {'predictions': array([2370.9292], dtype=float32)}
# {'predictions': array([941.94617], dtype=float32)}
# {'predictions': array([1766.7684], dtype=float32)}
# {'predictions': array([3373.7153], dtype=float32)}
# {'predictions': array([1346.0105], dtype=float32)}
# {'predictions': array([1512.0792], dtype=float32)}
# {'predictions': array([1730.6996], dtype=float32)}
# {'predictions': array([1074.8257], dtype=float32)}
# {'predictions': array([1186.2882], dtype=float32)}
# {'predictions': array([1470.4689], dtype=float32)}
# {'predictions': array([1896.809], dtype=float32)}
# {'predictions': array([1958.1859], dtype=float32)}
# {'predictions': array([1717.6781], dtype=float32)}
# {'predictions': array([1681.0021], dtype=float32)}
# {'predictions': array([1763.0837], dtype=float32)}
# {'predictions': array([2557.1653], dtype=float32)}
# {'predictions': array([1403.2268], dtype=float32)}
# {'predictions': array([901.6111], dtype=float32)}
# {'predictions': array([3703.762], dtype=float32)}
# {'predictions': array([1111.7972], dtype=float32)}
# {'predictions': array([1433.0668], dtype=float32)}
# {'predictions': array([1944.7069], dtype=float32)}
# {'predictions': array([2238.5715], dtype=float32)}
# {'predictions': array([1432.1954], dtype=float32)}
# {'predictions': array([2235.6401], dtype=float32)}
# {'predictions': array([1584.4193], dtype=float32)}
# {'predictions': array([2361.7673], dtype=float32)}
# {'predictions': array([1185.0641], dtype=float32)}
# {'predictions': array([1238.5001], dtype=float32)}
# {'predictions': array([944.9569], dtype=float32)}
# {'predictions': array([1034.465], dtype=float32)}
# {'predictions': array([1615.0946], dtype=float32)}
# {'predictions': array([1541.5056], dtype=float32)}
# {'predictions': array([1858.966], dtype=float32)}
# {'predictions': array([2101.858], dtype=float32)}
# {'predictions': array([1868.2203], dtype=float32)}
# {'predictions': array([2078.8105], dtype=float32)}
# {'predictions': array([1684.4497], dtype=float32)}
# {'predictions': array([1477.6012], dtype=float32)}
# {'predictions': array([1072.8958], dtype=float32)}
# {'predictions': array([1277.3954], dtype=float32)}
# {'predictions': array([1655.8561], dtype=float32)}
# {'predictions': array([2121.6064], dtype=float32)}
# {'predictions': array([2950.8086], dtype=float32)}
# {'predictions': array([1223.6606], dtype=float32)}
# {'predictions': array([1277.5573], dtype=float32)}
# {'predictions': array([1689.0891], dtype=float32)}
# {'predictions': array([2035.5184], dtype=float32)}
# {'predictions': array([1717.9994], dtype=float32)}
# {'predictions': array([1583.5481], dtype=float32)}
# {'predictions': array([1822.2645], dtype=float32)}
# {'predictions': array([1401.1667], dtype=float32)}
# {'predictions': array([3399.3752], dtype=float32)}
# {'predictions': array([1219.8396], dtype=float32)}
# {'predictions': array([2337.7917], dtype=float32)}
# {'predictions': array([1893.8511], dtype=float32)}
# {'predictions': array([986.9198], dtype=float32)}
# {'predictions': array([681.3091], dtype=float32)}
# {'predictions': array([2657.6094], dtype=float32)}
# {'predictions': array([1546.145], dtype=float32)}
# {'predictions': array([1024.3749], dtype=float32)}
# {'predictions': array([2412.0818], dtype=float32)}
# {'predictions': array([986.9198], dtype=float32)}
# {'predictions': array([1522.1307], dtype=float32)}
# {'predictions': array([2109.8345], dtype=float32)}
# {'predictions': array([1418.3363], dtype=float32)}
# {'predictions': array([2072.5159], dtype=float32)}
# {'predictions': array([944.08545], dtype=float32)}
# {'predictions': array([1575.945], dtype=float32)}
# {'predictions': array([1647.0468], dtype=float32)}
# {'predictions': array([1963.9589], dtype=float32)}
# {'predictions': array([1805.5316], dtype=float32)}
# {'predictions': array([2381.5156], dtype=float32)}
# {'predictions': array([1963.9589], dtype=float32)}
# {'predictions': array([2781.1091], dtype=float32)}
# {'predictions': array([2230.163], dtype=float32)}
# {'predictions': array([2161.6711], dtype=float32)}
# {'predictions': array([1029.4198], dtype=float32)}
# {'predictions': array([1462.8137], dtype=float32)}
# {'predictions': array([1856.0345], dtype=float32)}
# {'predictions': array([2397.4045], dtype=float32)}
# {'predictions': array([1499.4634], dtype=float32)}
# {'predictions': array([1007.55786], dtype=float32)}
# {'predictions': array([1847.49], dtype=float32)}
# {'predictions': array([2187.663], dtype=float32)}
# {'predictions': array([1689.0891], dtype=float32)}
# {'predictions': array([1007.55786], dtype=float32)}
# {'predictions': array([783.1664], dtype=float32)}
# {'predictions': array([5050.655], dtype=float32)}
# {'predictions': array([1856.3304], dtype=float32)}
# {'predictions': array([1459.9081], dtype=float32)}
# {'predictions': array([2397.4045], dtype=float32)}
# {'predictions': array([1433.0668], dtype=float32)}
# {'predictions': array([1504.5084], dtype=float32)}
# {'predictions': array([2960.7463], dtype=float32)}
# {'predictions': array([2029.5836], dtype=float32)}
# {'predictions': array([1549.5343], dtype=float32)}
# {'predictions': array([1720.2311], dtype=float32)}
# {'predictions': array([1858.8834], dtype=float32)}
# {'predictions': array([1763.4052], dtype=float32)}
# {'predictions': array([1099.7297], dtype=float32)}
# {'predictions': array([1488.497], dtype=float32)}
# {'predictions': array([1491.4283], dtype=float32)}
# {'predictions': array([2317.611], dtype=float32)}
# {'predictions': array([7068.204], dtype=float32)}
# {'predictions': array([1055.8693], dtype=float32)}
# {'predictions': array([2337.7917], dtype=float32)}
# {'predictions': array([1647.0724], dtype=float32)}
# {'predictions': array([1269.9022], dtype=float32)}
# {'predictions': array([2102.3289], dtype=float32)}
# {'predictions': array([2029.0701], dtype=float32)}
# {'predictions': array([1781.5823], dtype=float32)}
# {'predictions': array([767.84204], dtype=float32)}
# {'predictions': array([765.3938], dtype=float32)}
# {'predictions': array([1583.5481], dtype=float32)}
# {'predictions': array([1636.604], dtype=float32)}
# {'predictions': array([896.10834], dtype=float32)}
# {'predictions': array([1945.5782], dtype=float32)}
# {'predictions': array([1980.0222], dtype=float32)}
# {'predictions': array([1647.4525], dtype=float32)}
# {'predictions': array([1600.365], dtype=float32)}
# {'predictions': array([1098.1212], dtype=float32)}
# {'predictions': array([3915.1978], dtype=float32)}
# {'predictions': array([2042.2452], dtype=float32)}
# {'predictions': array([1763.8372], dtype=float32)}
# {'predictions': array([1443.5874], dtype=float32)}
# {'predictions': array([1771.0472], dtype=float32)}
# {'predictions': array([1101.7328], dtype=float32)}
# {'predictions': array([1847.49], dtype=float32)}
# {'predictions': array([2290.7039], dtype=float32)}
# {'predictions': array([2457.6238], dtype=float32)}
# {'predictions': array([3264.0293], dtype=float32)}
# {'predictions': array([514.82135], dtype=float32)}
# {'predictions': array([2189.0132], dtype=float32)}
# {'predictions': array([2363.8625], dtype=float32)}
# {'predictions': array([2093.0173], dtype=float32)}
# {'predictions': array([2141.4653], dtype=float32)}
# {'predictions': array([1316.5321], dtype=float32)}
# {'predictions': array([760.34875], dtype=float32)}
# {'predictions': array([1607.4652], dtype=float32)}
# {'predictions': array([2163.3274], dtype=float32)}
# {'predictions': array([1959.8677], dtype=float32)}
# {'predictions': array([1400.2954], dtype=float32)}
# {'predictions': array([1693.2317], dtype=float32)}
# {'predictions': array([1423.787], dtype=float32)}
# {'predictions': array([1503.6322], dtype=float32)}
# {'predictions': array([1185.0641], dtype=float32)}
# {'predictions': array([1822.2645], dtype=float32)}
# {'predictions': array([1601.9624], dtype=float32)}
# {'predictions': array([3034.0156], dtype=float32)}
# {'predictions': array([1509.1477], dtype=float32)}
# {'predictions': array([2168.6938], dtype=float32)}
# {'predictions': array([1994.7257], dtype=float32)}
# {'predictions': array([1709.2694], dtype=float32)}
# {'predictions': array([1639.3917], dtype=float32)}
# {'predictions': array([3030.624], dtype=float32)}
# {'predictions': array([2829.281], dtype=float32)}
# {'predictions': array([1517.1515], dtype=float32)}
# {'predictions': array([1508.6771], dtype=float32)}
# {'predictions': array([1657.1627], dtype=float32)}
# {'predictions': array([2027.1354], dtype=float32)}
# {'predictions': array([1766.7684], dtype=float32)}
# {'predictions': array([1635.7325], dtype=float32)}
# {'predictions': array([2397.4045], dtype=float32)}
# {'predictions': array([2214.2356], dtype=float32)}
# {'predictions': array([1273.2657], dtype=float32)}
# {'predictions': array([2363.8625], dtype=float32)}
# {'predictions': array([1665.5453], dtype=float32)}
# {'predictions': array([691.39923], dtype=float32)}
# {'predictions': array([1675.2036], dtype=float32)}
# {'predictions': array([1432.1954], dtype=float32)}
# {'predictions': array([1488.0392], dtype=float32)}
# {'predictions': array([1730.2289], dtype=float32)}
# {'predictions': array([1098.1212], dtype=float32)}
# {'predictions': array([1795.036], dtype=float32)}
# {'predictions': array([2346.174], dtype=float32)}
# {'predictions': array([3389.8828], dtype=float32)}
# {'predictions': array([2060.7173], dtype=float32)}
# {'predictions': array([1439.2957], dtype=float32)}
# {'predictions': array([1240.8558], dtype=float32)}
# {'predictions': array([2137.2915], dtype=float32)}
# {'predictions': array([1432.1954], dtype=float32)}
# {'predictions': array([1921.1632], dtype=float32)}
# {'predictions': array([1412.8207], dtype=float32)}
# {'predictions': array([1126.6368], dtype=float32)}
# {'predictions': array([2109.1604], dtype=float32)}
# {'predictions': array([2119.1714], dtype=float32)}
# {'predictions': array([2025.4281], dtype=float32)}
# {'predictions': array([1963.9589], dtype=float32)}
# {'predictions': array([1530.5392], dtype=float32)}
# {'predictions': array([1423.787], dtype=float32)}
# {'predictions': array([1437.7064], dtype=float32)}
# {'predictions': array([2694.7456], dtype=float32)}
# {'predictions': array([1766.7684], dtype=float32)}
# {'predictions': array([1959.7853], dtype=float32)}
# {'predictions': array([3136.2268], dtype=float32)}
# {'predictions': array([2086.2908], dtype=float32)}
# {'predictions': array([1400.2954], dtype=float32)}
# {'predictions': array([1800.8601], dtype=float32)}
# {'predictions': array([1439.2957], dtype=float32)}
# {'predictions': array([3068.4001], dtype=float32)}
# {'predictions': array([1103.8851], dtype=float32)}
# {'predictions': array([2736.7852], dtype=float32)}
# {'predictions': array([1973.6172], dtype=float32)}
# {'predictions': array([2029.113], dtype=float32)}
# {'predictions': array([1666.4169], dtype=float32)}
# {'predictions': array([4048.841], dtype=float32)}
# {'predictions': array([2737.1064], dtype=float32)}
# {'predictions': array([2521.8496], dtype=float32)}
# {'predictions': array([3050.8298], dtype=float32)}
# {'predictions': array([1689.0891], dtype=float32)}
# {'predictions': array([1348.1885], dtype=float32)}
# {'predictions': array([1847.9219], dtype=float32)}
# {'predictions': array([2102.7864], dtype=float32)}
# {'predictions': array([3305.2004], dtype=float32)}
# {'predictions': array([1675.957], dtype=float32)}
# {'predictions': array([2109.8345], dtype=float32)}
# {'predictions': array([1985.0107], dtype=float32)}
# {'predictions': array([1432.1954], dtype=float32)}
# {'predictions': array([2526.1414], dtype=float32)}
# {'predictions': array([1565.3971], dtype=float32)}
# {'predictions': array([1608.8256], dtype=float32)}
# {'predictions': array([2170.8074], dtype=float32)}
# {'predictions': array([1523.851], dtype=float32)}
# {'predictions': array([1690.7966], dtype=float32)}
# {'predictions': array([1638.1677], dtype=float32)}
# {'predictions': array([1432.1954], dtype=float32)}
# {'predictions': array([2521.0962], dtype=float32)}
# {'predictions': array([1637.7101], dtype=float32)}
# {'predictions': array([2161.6458], dtype=float32)}
# {'predictions': array([762.46246], dtype=float32)}
# {'predictions': array([1160.592], dtype=float32)}
# {'predictions': array([713.2356], dtype=float32)}
# {'predictions': array([1915.686], dtype=float32)}
# {'predictions': array([1504.5084], dtype=float32)}
# {'predictions': array([1485.6041], dtype=float32)}
# {'predictions': array([1185.0641], dtype=float32)}
# {'predictions': array([1366.6095], dtype=float32)}
# {'predictions': array([1858.13], dtype=float32)}
# {'predictions': array([1963.9589], dtype=float32)}
# {'predictions': array([1810.1713], dtype=float32)}
# {'predictions': array([8418.093], dtype=float32)}
# {'predictions': array([1444.7727], dtype=float32)}
# {'predictions': array([1692.7739], dtype=float32)}
# {'predictions': array([2126.6516], dtype=float32)}
# {'predictions': array([1726.8655], dtype=float32)}
# {'predictions': array([2119.9246], dtype=float32)}
# {'predictions': array([3802.9817], dtype=float32)}
# {'predictions': array([2768.7373], dtype=float32)}
# {'predictions': array([341.28534], dtype=float32)}
# {'predictions': array([1432.1954], dtype=float32)}
# {'predictions': array([1581.4606], dtype=float32)}
# {'predictions': array([2039.2032], dtype=float32)}
# {'predictions': array([1440.6041], dtype=float32)}
# {'predictions': array([1982.954], dtype=float32)}
# {'predictions': array([1622.2269], dtype=float32)}
# {'predictions': array([1444.341], dtype=float32)}
# {'predictions': array([3083.217], dtype=float32)}
# {'predictions': array([1521.6731], dtype=float32)}
# {'predictions': array([1238.7958], dtype=float32)}
# {'predictions': array([1015.9663], dtype=float32)}
# {'predictions': array([3368.2947], dtype=float32)}
# {'predictions': array([733.44165], dtype=float32)}
# {'predictions': array([1256.8937], dtype=float32)}
# {'predictions': array([1490.9706], dtype=float32)}
# {'predictions': array([1684.4497], dtype=float32)}
# {'predictions': array([1848.4183], dtype=float32)}
# {'predictions': array([4048.841], dtype=float32)}
# {'predictions': array([2032.5604], dtype=float32)}
# {'predictions': array([1692.4783], dtype=float32)}
# {'predictions': array([1773.174], dtype=float32)}
# {'predictions': array([341.28534], dtype=float32)}
# {'predictions': array([1661.7772], dtype=float32)}
# {'predictions': array([1521.6731], dtype=float32)}
# {'predictions': array([1791.6726], dtype=float32)}
# {'predictions': array([1689.8427], dtype=float32)}
# {'predictions': array([1763.8372], dtype=float32)}
# {'predictions': array([3010.0999], dtype=float32)}
# {'predictions': array([1800.8601], dtype=float32)}
# {'predictions': array([1441.4094], dtype=float32)}
# {'predictions': array([1444.7727], dtype=float32)}
# {'predictions': array([2530.6902], dtype=float32)}
# {'predictions': array([1458.2263], dtype=float32)}
# {'predictions': array([2175.395], dtype=float32)}
# {'predictions': array([1544.4066], dtype=float32)}
# {'predictions': array([1758.0387], dtype=float32)}
# {'predictions': array([1919.4814], dtype=float32)}
# {'predictions': array([1857.2587], dtype=float32)}
# {'predictions': array([4211.2646], dtype=float32)}
# {'predictions': array([1433.0668], dtype=float32)}
# {'predictions': array([1708.3412], dtype=float32)}
# {'predictions': array([2177.5344], dtype=float32)}
# {'predictions': array([1547.7699], dtype=float32)}
# {'predictions': array([1815.2162], dtype=float32)}
# {'predictions': array([1367.4149], dtype=float32)}
# {'predictions': array([1022.6931], dtype=float32)}
# {'predictions': array([1779.4686], dtype=float32)}
# {'predictions': array([1638.5814], dtype=float32)}
# {'predictions': array([1697.9032], dtype=float32)}
# {'predictions': array([1692.7739], dtype=float32)}
# {'predictions': array([2364.6985], dtype=float32)}
# {'predictions': array([1259.7865], dtype=float32)}
# {'predictions': array([1037.507], dtype=float32)}
# {'predictions': array([1730.6996], dtype=float32)}
# {'predictions': array([1546.6027], dtype=float32)}
# {'predictions': array([1702.8641], dtype=float32)}
# {'predictions': array([1160.2137], dtype=float32)}
# {'predictions': array([2526.5762], dtype=float32)}
# {'predictions': array([4522.887], dtype=float32)}
# {'predictions': array([1657.4585], dtype=float32)}
# {'predictions': array([4087.1877], dtype=float32)}
# {'predictions': array([1649.9781], dtype=float32)}
# {'predictions': array([1403.1442], dtype=float32)}
# {'predictions': array([1285.0118], dtype=float32)}
# {'predictions': array([1851.4033], dtype=float32)}
# {'predictions': array([2531.1604], dtype=float32)}
# {'predictions': array([1798.857], dtype=float32)}
# {'predictions': array([1748.7019], dtype=float32)}
# {'predictions': array([1403.201], dtype=float32)}
# {'predictions': array([1617.182], dtype=float32)}
# {'predictions': array([1773.4952], dtype=float32)}
# {'predictions': array([2516.7788], dtype=float32)}
# {'predictions': array([1541.1], dtype=float32)}
# {'predictions': array([1615.0946], dtype=float32)}
# {'predictions': array([1690.7709], dtype=float32)}
# {'predictions': array([2060.7173], dtype=float32)}
# {'predictions': array([1320.353], dtype=float32)}
# {'predictions': array([1098.8014], dtype=float32)}
# {'predictions': array([1803.7659], dtype=float32)}
# {'predictions': array([2032.4764], dtype=float32)}
# {'predictions': array([1022.6931], dtype=float32)}
# {'predictions': array([1615.0946], dtype=float32)}
# {'predictions': array([1487.6915], dtype=float32)}
# {'predictions': array([1469.1927], dtype=float32)}
# {'predictions': array([933.56335], dtype=float32)}
# {'predictions': array([1261.1284], dtype=float32)}
# {'predictions': array([5359.4043], dtype=float32)}
# {'predictions': array([937.35864], dtype=float32)}
# {'predictions': array([1618.026], dtype=float32)}
# {'predictions': array([1261.4938], dtype=float32)}
# {'predictions': array([2542.462], dtype=float32)}
# {'predictions': array([2107.3735], dtype=float32)}
# {'predictions': array([1449.0126], dtype=float32)}
# {'predictions': array([1739.8615], dtype=float32)}
# {'predictions': array([2109.8345], dtype=float32)}
# {'predictions': array([3351.4775], dtype=float32)}
# {'predictions': array([2197.7532], dtype=float32)}
# {'predictions': array([1963.6888], dtype=float32)}
# {'predictions': array([7744.1904], dtype=float32)}
# {'predictions': array([1800.8601], dtype=float32)}
# {'predictions': array([1575.945], dtype=float32)}
# {'predictions': array([1583.5481], dtype=float32)}
# {'predictions': array([714.48535], dtype=float32)}
# {'predictions': array([1595.2357], dtype=float32)}
# {'predictions': array([1102.9568], dtype=float32)}
# {'predictions': array([1448.1362], dtype=float32)}
# {'predictions': array([1728.0896], dtype=float32)}
# {'predictions': array([1649.9781], dtype=float32)}
# {'predictions': array([2168.6938], dtype=float32)}
# {'predictions': array([1074.8257], dtype=float32)}
# {'predictions': array([1854.2168], dtype=float32)}
# {'predictions': array([950.38025], dtype=float32)}
# {'predictions': array([1800.8601], dtype=float32)}
# {'predictions': array([2354.6086], dtype=float32)}
# {'predictions': array([2701.0376], dtype=float32)}
# {'predictions': array([2026.2997], dtype=float32)}
# {'predictions': array([761.57275], dtype=float32)}
# {'predictions': array([2863.7861], dtype=float32)}
# {'predictions': array([986.9198], dtype=float32)}
# {'predictions': array([982.33246], dtype=float32)}
# {'predictions': array([1662.9612], dtype=float32)}
# {'predictions': array([3232.7488], dtype=float32)}
# {'predictions': array([1687.0027], dtype=float32)}
# {'predictions': array([2109.513], dtype=float32)}
# {'predictions': array([2685.9023], dtype=float32)}
# {'predictions': array([1635.7325], dtype=float32)}
# {'predictions': array([308.16797], dtype=float32)}
# {'predictions': array([3834.9338], dtype=float32)}
# {'predictions': array([1488.9674], dtype=float32)}
# {'predictions': array([2028.3596], dtype=float32)}
# {'predictions': array([1636.9303], dtype=float32)}
# {'predictions': array([1801.7885], dtype=float32)}
# {'predictions': array([1549.5343], dtype=float32)}
# {'predictions': array([2168.6938], dtype=float32)}
# {'predictions': array([1826.0856], dtype=float32)}
# {'predictions': array([1871.0338], dtype=float32)}
# {'predictions': array([1339.2837], dtype=float32)}
# {'predictions': array([2035.5184], dtype=float32)}
# {'predictions': array([1143.7494], dtype=float32)}
# {'predictions': array([1615.0946], dtype=float32)}
# {'predictions': array([3373.7153], dtype=float32)}
# {'predictions': array([1366.2295], dtype=float32)}
# {'predictions': array([2194.8218], dtype=float32)}
# {'predictions': array([1488.497], dtype=float32)}
# {'predictions': array([1802.0842], dtype=float32)}
# {'predictions': array([1600.365], dtype=float32)}
# {'predictions': array([1623.5287], dtype=float32)}
# {'predictions': array([1381.7968], dtype=float32)}
# {'predictions': array([1875.3253], dtype=float32)}
# {'predictions': array([4086.0093], dtype=float32)}
# {'predictions': array([1337.1443], dtype=float32)}
# {'predictions': array([1850.8534], dtype=float32)}
# {'predictions': array([950.38025], dtype=float32)}
# {'predictions': array([1348.982], dtype=float32)}
# {'predictions': array([1611.7048], dtype=float32)}
# {'predictions': array([2267.1604], dtype=float32)}
# {'predictions': array([1725.1582], dtype=float32)}
# {'predictions': array([1727.7682], dtype=float32)}
# {'predictions': array([1339.3224], dtype=float32)}
# {'predictions': array([1423.787], dtype=float32)}
# {'predictions': array([1875.3253], dtype=float32)}
# {'predictions': array([3480.5422], dtype=float32)}
# {'predictions': array([1433.0668], dtype=float32)}
# {'predictions': array([1717.9994], dtype=float32)}
# {'predictions': array([1755.4287], dtype=float32)}
# {'predictions': array([2864.139], dtype=float32)}
# {'predictions': array([1443.5616], dtype=float32)}
# {'predictions': array([1635.7325], dtype=float32)}
# {'predictions': array([3946.797], dtype=float32)}
# {'predictions': array([1119.4779], dtype=float32)}
# {'predictions': array([1770.564], dtype=float32)}
# {'predictions': array([1499.4634], dtype=float32)}
# {'predictions': array([1381.7968], dtype=float32)}
# {'predictions': array([1398.5616], dtype=float32)}
# {'predictions': array([1473.8322], dtype=float32)}
# {'predictions': array([1364.0515], dtype=float32)}
# {'predictions': array([514.82135], dtype=float32)}
# {'predictions': array([2287.3408], dtype=float32)}
# {'predictions': array([1524.2567], dtype=float32)}
# {'predictions': array([1453.1813], dtype=float32)}
# {'predictions': array([1428.4265], dtype=float32)}
# {'predictions': array([1736.9557], dtype=float32)}
# {'predictions': array([2105.26], dtype=float32)}
# {'predictions': array([1717.9994], dtype=float32)}
# {'predictions': array([1625.1847], dtype=float32)}
# {'predictions': array([3190.4104], dtype=float32)}
# {'predictions': array([2960.7463], dtype=float32)}
# {'predictions': array([2163.6487], dtype=float32)}
# {'predictions': array([2138.4233], dtype=float32)}
# {'predictions': array([2121.6064], dtype=float32)}
# {'predictions': array([2121.6064], dtype=float32)}
# {'predictions': array([1537.6798], dtype=float32)}
# {'predictions': array([1423.787], dtype=float32)}
# {'predictions': array([1297.66], dtype=float32)}
# {'predictions': array([2001.4524], dtype=float32)}
# {'predictions': array([3903.7444], dtype=float32)}
# {'predictions': array([1791.6984], dtype=float32)}
# {'predictions': array([1403.1442], dtype=float32)}
# {'predictions': array([1019.3298], dtype=float32)}
# {'predictions': array([1019.3298], dtype=float32)}
# {'predictions': array([973.92395], dtype=float32)}
# {'predictions': array([1687.381], dtype=float32)}
# {'predictions': array([1015.9663], dtype=float32)}
# {'predictions': array([2363.3489], dtype=float32)}
# {'predictions': array([1264.0261], dtype=float32)}
# {'predictions': array([1982.954], dtype=float32)}
# {'predictions': array([1554.9594], dtype=float32)}
# {'predictions': array([1691.5499], dtype=float32)}
# {'predictions': array([1443.5616], dtype=float32)}
# {'predictions': array([2460.5554], dtype=float32)}
# {'predictions': array([34.122585], dtype=float32)}
# {'predictions': array([1473.8579], dtype=float32)}
# {'predictions': array([1857.2587], dtype=float32)}
# {'predictions': array([765.3938], dtype=float32)}
# {'predictions': array([1620.1133], dtype=float32)}
# {'predictions': array([2027.1354], dtype=float32)}
# {'predictions': array([2539.595], dtype=float32)}
# {'predictions': array([1691.6422], dtype=float32)}
# {'predictions': array([1591.1461], dtype=float32)}
# {'predictions': array([1728.0896], dtype=float32)}
# {'predictions': array([2196.5293], dtype=float32)}
# {'predictions': array([1665.5453], dtype=float32)}
# {'predictions': array([1082.4806], dtype=float32)}
# {'predictions': array([1266.2174], dtype=float32)}
# {'predictions': array([1182.2058], dtype=float32)}
# {'predictions': array([1822.6967], dtype=float32)}
# {'predictions': array([1745.0685], dtype=float32)}
# {'predictions': array([1224.4965], dtype=float32)}
# {'predictions': array([2024.204], dtype=float32)}
# {'predictions': array([1238.5001], dtype=float32)}
# {'predictions': array([2197.7532], dtype=float32)}
# {'predictions': array([182.36256], dtype=float32)}
# {'predictions': array([1608.6893], dtype=float32)}
# {'predictions': array([1824.3783], dtype=float32)}
# {'predictions': array([1432.1954], dtype=float32)}
# {'predictions': array([1605.8759], dtype=float32)}
# {'predictions': array([1459.9081], dtype=float32)}
# {'predictions': array([1188.8026], dtype=float32)}
# {'predictions': array([1441.4094], dtype=float32)}
# {'predictions': array([1902.6643], dtype=float32)}
# {'predictions': array([1575.945], dtype=float32)}
# {'predictions': array([1763.8372], dtype=float32)}
# {'predictions': array([1332.1653], dtype=float32)}
# {'predictions': array([1417.9838], dtype=float32)}
# {'predictions': array([1437.7064], dtype=float32)}
# {'predictions': array([3853.765], dtype=float32)}
# {'predictions': array([1853.8953], dtype=float32)}
# {'predictions': array([1621.8214], dtype=float32)}
# {'predictions': array([1166.8356], dtype=float32)}
# {'predictions': array([1348.1108], dtype=float32)}
# {'predictions': array([1698.7473], dtype=float32)}
# {'predictions': array([1689.9606], dtype=float32)}
# {'predictions': array([2889.0117], dtype=float32)}
# {'predictions': array([1689.7996], dtype=float32)}
# {'predictions': array([1615.0946], dtype=float32)}
# {'predictions': array([1575.945], dtype=float32)}
# {'predictions': array([1860.1901], dtype=float32)}
# {'predictions': array([2359.196], dtype=float32)}
# {'predictions': array([1567.5752], dtype=float32)}
# {'predictions': array([3958.0298], dtype=float32)}
# {'predictions': array([1858.966], dtype=float32)}
# {'predictions': array([1781.1504], dtype=float32)}
# {'predictions': array([1517.2067], dtype=float32)}
# {'predictions': array([1417.9315], dtype=float32)}
# {'predictions': array([2964.8015], dtype=float32)}
# {'predictions': array([1490.9706], dtype=float32)}
# {'predictions': array([4047.1462], dtype=float32)}
# {'predictions': array([1097.2499], dtype=float32)}
# {'predictions': array([1689.8427], dtype=float32)}
# {'predictions': array([2317.611], dtype=float32)}
# {'predictions': array([1106.5297], dtype=float32)}
# {'predictions': array([2357.8196], dtype=float32)}
# {'predictions': array([3533.911], dtype=float32)}
# {'predictions': array([1317.4218], dtype=float32)}
# {'predictions': array([1182.2058], dtype=float32)}
# {'predictions': array([1581.8663], dtype=float32)}
# {'predictions': array([1605.0044], dtype=float32)}
# {'predictions': array([1424.6583], dtype=float32)}
# {'predictions': array([1860.9436], dtype=float32)}
# {'predictions': array([4544.609], dtype=float32)}
# {'predictions': array([2109.513], dtype=float32)}
# {'predictions': array([1372.0023], dtype=float32)}
# {'predictions': array([1698.7745], dtype=float32)}
# {'predictions': array([2862.915], dtype=float32)}
# {'predictions': array([2103.1077], dtype=float32)}
# {'predictions': array([4040.9717], dtype=float32)}
# {'predictions': array([941.94617], dtype=float32)}
# {'predictions': array([2088.5222], dtype=float32)}
# {'predictions': array([1100.8969], dtype=float32)}
# {'predictions': array([1520.9454], dtype=float32)}
# {'predictions': array([6450.928], dtype=float32)}
# {'predictions': array([2032.4764], dtype=float32)}
# {'predictions': array([1689.0891], dtype=float32)}
# {'predictions': array([1665.5453], dtype=float32)}
# {'predictions': array([1960.7136], dtype=float32)}
# {'predictions': array([1662.9612], dtype=float32)}
# {'predictions': array([1943.3209], dtype=float32)}
# {'predictions': array([729.7001], dtype=float32)}
# {'predictions': array([1662.9612], dtype=float32)}
# {'predictions': array([1398.5616], dtype=float32)}
# {'predictions': array([3138.278], dtype=float32)}
# {'predictions': array([1307.7758], dtype=float32)}
# {'predictions': array([1299.7151], dtype=float32)}
# {'predictions': array([1857.2587], dtype=float32)}
# {'predictions': array([1536.0807], dtype=float32)}
# {'predictions': array([1460.7795], dtype=float32)}
# {'predictions': array([1858.13], dtype=float32)}
# {'predictions': array([2170.8074], dtype=float32)}
# {'predictions': array([1808.4896], dtype=float32)}
# {'predictions': array([1448.1749], dtype=float32)}
# {'predictions': array([2428.603], dtype=float32)}
# {'predictions': array([1690.7709], dtype=float32)}
# {'predictions': array([1348.1108], dtype=float32)}
# {'predictions': array([1374.1416], dtype=float32)}
# {'predictions': array([1318.6458], dtype=float32)}
# {'predictions': array([3834.9338], dtype=float32)}
# {'predictions': array([1024.3749], dtype=float32)}
# {'predictions': array([1436.835], dtype=float32)}
# {'predictions': array([1557.485], dtype=float32)}
# {'predictions': array([1264.8976], dtype=float32)}
# {'predictions': array([765.3938], dtype=float32)}
# {'predictions': array([1264.0261], dtype=float32)}
# {'predictions': array([1683.2806], dtype=float32)}
# {'predictions': array([1857.2587], dtype=float32)}
# {'predictions': array([1546.145], dtype=float32)}
# {'predictions': array([1944.7069], dtype=float32)}
# {'predictions': array([773.8023], dtype=float32)}
# {'predictions': array([1507.034], dtype=float32)}
# {'predictions': array([1432.1954], dtype=float32)}
# {'predictions': array([1542.3112], dtype=float32)}
# {'predictions': array([1398.5616], dtype=float32)}
# {'predictions': array([1267.0889], dtype=float32)}
# {'predictions': array([931.8816], dtype=float32)}
# {'predictions': array([5586.8906], dtype=float32)}
# {'predictions': array([2779.7014], dtype=float32)}
# {'predictions': array([1348.1108], dtype=float32)}
# {'predictions': array([639.2667], dtype=float32)}
# {'predictions': array([1959.4102], dtype=float32)}
# {'predictions': array([1966.8904], dtype=float32)}
# {'predictions': array([1763.4052], dtype=float32)}
# {'predictions': array([2447.5593], dtype=float32)}
# {'predictions': array([6898.15], dtype=float32)}
# {'predictions': array([3367.423], dtype=float32)}
# {'predictions': array([929.8784], dtype=float32)}
# {'predictions': array([2364.6985], dtype=float32)}
# {'predictions': array([5051.396], dtype=float32)}
# {'predictions': array([2963.8167], dtype=float32)}
# {'predictions': array([5359.4043], dtype=float32)}
# {'predictions': array([2022.9362], dtype=float32)}
# {'predictions': array([712.88306], dtype=float32)}
# {'predictions': array([1584.4193], dtype=float32)}
# {'predictions': array([1544.4371], dtype=float32)}
# {'predictions': array([2359.196], dtype=float32)}
# {'predictions': array([1320.353], dtype=float32)}
# {'predictions': array([1967.0262], dtype=float32)}
# {'predictions': array([1968.2241], dtype=float32)}
# {'predictions': array([2180.4656], dtype=float32)}
# {'predictions': array([714.943], dtype=float32)}
# {'predictions': array([2195.1794], dtype=float32)}
# {'predictions': array([1927.89], dtype=float32)}
# {'predictions': array([1625.5905], dtype=float32)}
# {'predictions': array([2402.1282], dtype=float32)}
# {'predictions': array([1875.3253], dtype=float32)}
# {'predictions': array([3052.9832], dtype=float32)}
# {'predictions': array([1649.9781], dtype=float32)}
# {'predictions': array([1017.648], dtype=float32)}
# {'predictions': array([1224.4965], dtype=float32)}
# {'predictions': array([1098.8014], dtype=float32)}
# {'predictions': array([1307.7758], dtype=float32)}
# {'predictions': array([177.14769], dtype=float32)}
# {'predictions': array([973.08813], dtype=float32)}
# {'predictions': array([1959.8422], dtype=float32)}
# {'predictions': array([893.20264], dtype=float32)}
# {'predictions': array([1615.0946], dtype=float32)}
# {'predictions': array([1730.2289], dtype=float32)}
# {'predictions': array([1980.0222], dtype=float32)}
# {'predictions': array([2106.903], dtype=float32)}
# {'predictions': array([898.6797], dtype=float32)}
# {'predictions': array([2052.361], dtype=float32)}
# {'predictions': array([1335.0306], dtype=float32)}
# {'predictions': array([1800.8601], dtype=float32)}
# {'predictions': array([1647.0724], dtype=float32)}
# {'predictions': array([1805.0997], dtype=float32)}
# {'predictions': array([1541.5056], dtype=float32)}
# {'predictions': array([2411.7864], dtype=float32)}
# {'predictions': array([1524.2567], dtype=float32)}
# {'predictions': array([1491.4283], dtype=float32)}
# {'predictions': array([982.33246], dtype=float32)}
# {'predictions': array([1698.7473], dtype=float32)}
# {'predictions': array([1528.518], dtype=float32)}
# {'predictions': array([765.3938], dtype=float32)}
# {'predictions': array([1398.5616], dtype=float32)}
# {'predictions': array([1007.55786], dtype=float32)}
# {'predictions': array([944.08545], dtype=float32)}
# {'predictions': array([1374.9337], dtype=float32)}
# {'predictions': array([1356.5192], dtype=float32)}
# {'predictions': array([1128.2616], dtype=float32)}
# {'predictions': array([1973.6172], dtype=float32)}
# {'predictions': array([2578.7314], dtype=float32)}
# {'predictions': array([1199.2711], dtype=float32)}
# {'predictions': array([1777.3292], dtype=float32)}
# {'predictions': array([1684.4497], dtype=float32)}
# {'predictions': array([1433.5886], dtype=float32)}
# {'predictions': array([1728.0896], dtype=float32)}
# {'predictions': array([1958.914], dtype=float32)}
# {'predictions': array([767.84204], dtype=float32)}
# {'predictions': array([821.3218], dtype=float32)}
# {'predictions': array([2359.6309], dtype=float32)}
# {'predictions': array([1675.957], dtype=float32)}
# {'predictions': array([2072.5413], dtype=float32)}
# {'predictions': array([1060.9144], dtype=float32)}
# {'predictions': array([1019.3298], dtype=float32)}
# {'predictions': array([1608.6893], dtype=float32)}
# ...
# {'predictions': array([1266.2174], dtype=float32)}
# {'predictions': array([1739.9456], dtype=float32)}
# {'predictions': array([1679.7524], dtype=float32)}
# {'predictions': array([1434.4598], dtype=float32)}
# {'predictions': array([1748.7405], dtype=float32)}
# {'predictions': array([4223.1313], dtype=float32)}
# {'predictions': array([1963.9589], dtype=float32)}
# {'predictions': array([2453.8286], dtype=float32)}
# {'predictions': array([1277.5573], dtype=float32)}
# {'predictions': array([2119.1714], dtype=float32)}
# {'predictions': array([1597.0016], dtype=float32)}
# {'predictions': array([1770.564], dtype=float32)}
# {'predictions': array([3802.9817], dtype=float32)}
# {'predictions': array([1657.1627], dtype=float32)}
# {'predictions': array([1237.4923], dtype=float32)}
# {'predictions': array([1620.1133], dtype=float32)}
# {'predictions': array([1615.966], dtype=float32)}
# {'predictions': array([4607.6206], dtype=float32)}
# {'predictions': array([2526.1414], dtype=float32)}
# {'predictions': array([1444.341], dtype=float32)}
# {'predictions': array([1599.149], dtype=float32)}
# {'predictions': array([2127.0835], dtype=float32)}
# {'predictions': array([933.56335], dtype=float32)}
# {'predictions': array([1673.9796], dtype=float32)}
# {'predictions': array([3704.633], dtype=float32)}
# {'predictions': array([2866.2756], dtype=float32)}
# {'predictions': array([1753.747], dtype=float32)}
# {'predictions': array([2105.26], dtype=float32)}
# {'predictions': array([1433.0668], dtype=float32)}
# {'predictions': array([2542.462], dtype=float32)}
# {'predictions': array([1709.2694], dtype=float32)}
# {'predictions': array([4378.7183], dtype=float32)}
# {'predictions': array([986.9198], dtype=float32)}
# {'predictions': array([1985.0107], dtype=float32)}
# {'predictions': array([1520.9454], dtype=float32)}
# {'predictions': array([3174.0283], dtype=float32)}
# {'predictions': array([2063.6753], dtype=float32)}
# {'predictions': array([2526.5762], dtype=float32)}
# {'predictions': array([1443.5874], dtype=float32)}
# {'predictions': array([1860.9436], dtype=float32)}
# {'predictions': array([1516.2804], dtype=float32)}
# {'predictions': array([1295.22], dtype=float32)}
# {'predictions': array([1652.8453], dtype=float32)}
# {'predictions': array([2094.8352], dtype=float32)}
# {'predictions': array([1607.9359], dtype=float32)}
# {'predictions': array([1432.1954], dtype=float32)}
# {'predictions': array([1781.1504], dtype=float32)}
# {'predictions': array([2122.0383], dtype=float32)}
# {'predictions': array([2168.6938], dtype=float32)}
# {'predictions': array([3367.423], dtype=float32)}
# {'predictions': array([2168.6938], dtype=float32)}
# {'predictions': array([1758.91], dtype=float32)}
# {'predictions': array([1152.1836], dtype=float32)}
# {'predictions': array([1766.7684], dtype=float32)}
# {'predictions': array([1159.8386], dtype=float32)}
# {'predictions': array([1717.9994], dtype=float32)}
# {'predictions': array([2349.9954], dtype=float32)}
# {'predictions': array([1081.9845], dtype=float32)}
# {'predictions': array([1198.2561], dtype=float32)}
# {'predictions': array([1126.6368], dtype=float32)}
# {'predictions': array([1017.648], dtype=float32)}
# {'predictions': array([1007.55786], dtype=float32)}
# {'predictions': array([2365.452], dtype=float32)}
# {'predictions': array([1098.1212], dtype=float32)}
# {'predictions': array([1441.4094], dtype=float32)}
# {'predictions': array([2785.1223], dtype=float32)}
# {'predictions': array([1545.2426], dtype=float32)}
# {'predictions': array([711.5796], dtype=float32)}
# {'predictions': array([1856.3304], dtype=float32)}
# {'predictions': array([1605.0044], dtype=float32)}
# {'predictions': array([1745.3385], dtype=float32)}
# {'predictions': array([1739.8615], dtype=float32)}
# {'predictions': array([1237.4923], dtype=float32)}
# {'predictions': array([3879.4475], dtype=float32)}
# {'predictions': array([1433.0668], dtype=float32)}
# {'predictions': array([1654.1743], dtype=float32)}
# {'predictions': array([2443.369], dtype=float32)}
# {'predictions': array([1810.1713], dtype=float32)}
# {'predictions': array([1976.2269], dtype=float32)}
# {'predictions': array([1390.069], dtype=float32)}
# {'predictions': array([4881.4937], dtype=float32)}
# {'predictions': array([1810.1713], dtype=float32)}
# {'predictions': array([2520.7205], dtype=float32)}
# {'predictions': array([1747.5165], dtype=float32)}
# {'predictions': array([1822.2645], dtype=float32)}
# {'predictions': array([1348.1108], dtype=float32)}
# {'predictions': array([1212.1122], dtype=float32)}
# {'predictions': array([1741.1649], dtype=float32)}
# {'predictions': array([2363.3918], dtype=float32)}
# {'predictions': array([1227.8599], dtype=float32)}
# {'predictions': array([1662.9612], dtype=float32)}
# {'predictions': array([3368.2947], dtype=float32)}
# {'predictions': array([1273.358], dtype=float32)}
# {'predictions': array([1040.4384], dtype=float32)}
# {'predictions': array([2472.7021], dtype=float32)}
# {'predictions': array([1454.5234], dtype=float32)}
# {'predictions': array([1615.0946], dtype=float32)}
# {'predictions': array([4240.222], dtype=float32)}
# {'predictions': array([2258.3762], dtype=float32)}
# {'predictions': array([1603.2963], dtype=float32)}
# {'predictions': array([3368.2947], dtype=float32)}
# {'predictions': array([1517.2067], dtype=float32)}
# {'predictions': array([1896.3953], dtype=float32)}
# {'predictions': array([1017.648], dtype=float32)}
# {'predictions': array([1988.434], dtype=float32)}
# {'predictions': array([1800.8601], dtype=float32)}
# {'predictions': array([1550.7855], dtype=float32)}
# {'predictions': array([1692.7739], dtype=float32)}
# {'predictions': array([9712.49], dtype=float32)}
# {'predictions': array([1189.1553], dtype=float32)}
# {'predictions': array([1562.0594], dtype=float32)}
# {'predictions': array([1622.2269], dtype=float32)}
# {'predictions': array([1098.8014], dtype=float32)}
# {'predictions': array([2202.0317], dtype=float32)}
# {'predictions': array([1601.2362], dtype=float32)}
# {'predictions': array([2516.7788], dtype=float32)}
# {'predictions': array([1763.4052], dtype=float32)}
# {'predictions': array([4007.3381], dtype=float32)}
# {'predictions': array([2187.663], dtype=float32)}
# {'predictions': array([762.46246], dtype=float32)}
# {'predictions': array([1428.4265], dtype=float32)}
# {'predictions': array([1675.957], dtype=float32)}
# {'predictions': array([2694.7456], dtype=float32)}
# {'predictions': array([1615.0946], dtype=float32)}
# {'predictions': array([1423.787], dtype=float32)}
# {'predictions': array([1919.5863], dtype=float32)}
# {'predictions': array([1443.5616], dtype=float32)}
# {'predictions': array([1845.43], dtype=float32)}
# {'predictions': array([1195.1285], dtype=float32)}
# {'predictions': array([1160.592], dtype=float32)}
# {'predictions': array([1630.2299], dtype=float32)}
# {'predictions': array([1980.0222], dtype=float32)}
# {'predictions': array([1638.664], dtype=float32)}
# {'predictions': array([1803.4445], dtype=float32)}
# {'predictions': array([1813.8561], dtype=float32)}
# {'predictions': array([1662.9612], dtype=float32)}
# {'predictions': array([1729.7714], dtype=float32)}
# {'predictions': array([1709.2694], dtype=float32)}
# {'predictions': array([1044.0975], dtype=float32)}
# {'predictions': array([1044.0975], dtype=float32)}
# {'predictions': array([944.08545], dtype=float32)}
# {'predictions': array([1689.9606], dtype=float32)}
# {'predictions': array([2121.6064], dtype=float32)}
# {'predictions': array([1242.9951], dtype=float32)}
# {'predictions': array([1569.6625], dtype=float32)}
# {'predictions': array([1079.5494], dtype=float32)}
# {'predictions': array([2362.9915], dtype=float32)}
# {'predictions': array([4048.841], dtype=float32)}
# {'predictions': array([1802.0842], dtype=float32)}
# {'predictions': array([1662.9612], dtype=float32)}
# {'predictions': array([1541.1], dtype=float32)}
# {'predictions': array([1044.0975], dtype=float32)}
# {'predictions': array([1564.6437], dtype=float32)}
# {'predictions': array([1673.1437], dtype=float32)}
# {'predictions': array([792.30096], dtype=float32)}
# {'predictions': array([1095.504], dtype=float32)}
# {'predictions': array([1242.2161], dtype=float32)}
# {'predictions': array([1139.162], dtype=float32)}
# {'predictions': array([2516.7788], dtype=float32)}
# {'predictions': array([1922.4128], dtype=float32)}
# {'predictions': array([1100.8969], dtype=float32)}
# {'predictions': array([1855.5505], dtype=float32)}
# {'predictions': array([3367.423], dtype=float32)}
# {'predictions': array([1057.551], dtype=float32)}
# {'predictions': array([2295.253], dtype=float32)}
# {'predictions': array([765.3938], dtype=float32)}
# {'predictions': array([1374.1416], dtype=float32)}
# {'predictions': array([2294.0676], dtype=float32)}
# {'predictions': array([1724.7262], dtype=float32)}
# {'predictions': array([2058.6304], dtype=float32)}
# {'predictions': array([1034.465], dtype=float32)}
# {'predictions': array([1763.8372], dtype=float32)}
# {'predictions': array([1690.7709], dtype=float32)}
# {'predictions': array([1615.416], dtype=float32)}
# {'predictions': array([2168.6938], dtype=float32)}
# {'predictions': array([1635.7325], dtype=float32)}
# {'predictions': array([1578.8763], dtype=float32)}
# {'predictions': array([1007.55786], dtype=float32)}
# {'predictions': array([1277.5573], dtype=float32)}
# {'predictions': array([1516.2804], dtype=float32)}
# {'predictions': array([1098.1212], dtype=float32)}
# {'predictions': array([3211.3574], dtype=float32)}
# {'predictions': array([2597.2043], dtype=float32)}
# {'predictions': array([1142.0934], dtype=float32)}
# {'predictions': array([1503.6322], dtype=float32)}
# {'predictions': array([767.84204], dtype=float32)}
# {'predictions': array([1619.682], dtype=float32)}
# {'predictions': array([1517.2067], dtype=float32)}
# {'predictions': array([1855.5505], dtype=float32)}
# {'predictions': array([3232.7488], dtype=float32)}
# {'predictions': array([1024.8068], dtype=float32)}
# {'predictions': array([1041.1661], dtype=float32)}
# {'predictions': array([1398.5616], dtype=float32)}
# {'predictions': array([1605.7578], dtype=float32)}
# {'predictions': array([842.7518], dtype=float32)}
# {'predictions': array([1669.3145], dtype=float32)}
# {'predictions': array([619.0864], dtype=float32)}
# {'predictions': array([1855.8984], dtype=float32)}
# {'predictions': array([1520.9196], dtype=float32)}
# {'predictions': array([1214.8768], dtype=float32)}
# {'predictions': array([1320.353], dtype=float32)}
# {'predictions': array([1300.1727], dtype=float32)}
# {'predictions': array([1432.1954], dtype=float32)}
# {'predictions': array([1684.4497], dtype=float32)}
# {'predictions': array([1370.8441], dtype=float32)}
# {'predictions': array([1605.7578], dtype=float32)}
# {'predictions': array([2701.0376], dtype=float32)}
# {'predictions': array([1275.418], dtype=float32)}
# {'predictions': array([2557.1653], dtype=float32)}
# {'predictions': array([2039.2032], dtype=float32)}
# {'predictions': array([1730.6996], dtype=float32)}
# {'predictions': array([733.44165], dtype=float32)}
# {'predictions': array([4377.847], dtype=float32)}
# {'predictions': array([2364.6985], dtype=float32)}
# {'predictions': array([1802.0842], dtype=float32)}
# {'predictions': array([2191.986], dtype=float32)}
# {'predictions': array([1776.8588], dtype=float32)}
# {'predictions': array([1219.8396], dtype=float32)}
# {'predictions': array([1074.8257], dtype=float32)}
# {'predictions': array([1274.464], dtype=float32)}
# {'predictions': array([1157.995], dtype=float32)}
# {'predictions': array([2028.3596], dtype=float32)}
# {'predictions': array([1432.1954], dtype=float32)}
# {'predictions': array([2512.6877], dtype=float32)}
# {'predictions': array([1860.9436], dtype=float32)}
# {'predictions': array([2369.7437], dtype=float32)}
# {'predictions': array([1647.8002], dtype=float32)}
# {'predictions': array([1934.2118], dtype=float32)}
# {'predictions': array([3373.9426], dtype=float32)}
# {'predictions': array([1660.9011], dtype=float32)}
# {'predictions': array([2109.513], dtype=float32)}
# {'predictions': array([3533.911], dtype=float32)}
# {'predictions': array([1595.2357], dtype=float32)}
# {'predictions': array([1432.1954], dtype=float32)}
# {'predictions': array([1448.1362], dtype=float32)}
# {'predictions': array([1457.4209], dtype=float32)}
# {'predictions': array([1582.2399], dtype=float32)}
# {'predictions': array([1369.9728], dtype=float32)}
# {'predictions': array([3083.217], dtype=float32)}
# {'predictions': array([1725.1582], dtype=float32)}
# {'predictions': array([932.8098], dtype=float32)}
# {'predictions': array([1098.8014], dtype=float32)}
# {'predictions': array([3661.2874], dtype=float32)}
# {'predictions': array([1858.966], dtype=float32)}
# {'predictions': array([1510.0192], dtype=float32)}
# {'predictions': array([1355.211], dtype=float32)}
# {'predictions': array([3031.0842], dtype=float32)}
# {'predictions': array([1352.2797], dtype=float32)}
# {'predictions': array([6397.9756], dtype=float32)}
# {'predictions': array([1768.1545], dtype=float32)}
# {'predictions': array([1776.1053], dtype=float32)}
# {'predictions': array([1348.1108], dtype=float32)}
# {'predictions': array([2028.3596], dtype=float32)}
# {'predictions': array([1570.0946], dtype=float32)}
# {'predictions': array([3658.356], dtype=float32)}
# {'predictions': array([1530.6051], dtype=float32)}
# {'predictions': array([2260.8655], dtype=float32)}
# {'predictions': array([1444.7727], dtype=float32)}
# {'predictions': array([2529.9368], dtype=float32)}
# {'predictions': array([2230.163], dtype=float32)}
# {'predictions': array([1304.8444], dtype=float32)}
# {'predictions': array([1625.5905], dtype=float32)}
# {'predictions': array([2196.5293], dtype=float32)}
# {'predictions': array([4346.214], dtype=float32)}
# {'predictions': array([1013.9632], dtype=float32)}
# {'predictions': array([1733.5667], dtype=float32)}
# {'predictions': array([2210.7363], dtype=float32)}
# {'predictions': array([1533.445], dtype=float32)}
# {'predictions': array([1415.7521], dtype=float32)}
# {'predictions': array([3802.9817], dtype=float32)}
# {'predictions': array([3704.9863], dtype=float32)}
# {'predictions': array([2218.3914], dtype=float32)}
# {'predictions': array([2291.4575], dtype=float32)}
# {'predictions': array([1041.1661], dtype=float32)}
# {'predictions': array([2448.7834], dtype=float32)}
# {'predictions': array([2173.739], dtype=float32)}
# {'predictions': array([1606.6732], dtype=float32)}
# {'predictions': array([1063.0941], dtype=float32)}
# {'predictions': array([2284.4094], dtype=float32)}
# {'predictions': array([1666.4169], dtype=float32)}
# {'predictions': array([1057.551], dtype=float32)}
# {'predictions': array([1189.4896], dtype=float32)}
# {'predictions': array([1648.7543], dtype=float32)}
# {'predictions': array([4379.434], dtype=float32)}
# {'predictions': array([1577.6654], dtype=float32)}
# {'predictions': array([2105.26], dtype=float32)}
# {'predictions': array([1557.485], dtype=float32)}
# {'predictions': array([1439.7278], dtype=float32)}
# {'predictions': array([765.3938], dtype=float32)}
# {'predictions': array([932.8098], dtype=float32)}
# {'predictions': array([1875.3253], dtype=float32)}
# {'predictions': array([1443.5874], dtype=float32)}
# {'predictions': array([5051.396], dtype=float32)}
# {'predictions': array([1470.4689], dtype=float32)}
# {'predictions': array([2238.5715], dtype=float32)}
# {'predictions': array([6007.6826], dtype=float32)}
# {'predictions': array([1237.4923], dtype=float32)}
# {'predictions': array([2027.1354], dtype=float32)}
# {'predictions': array([810.79956], dtype=float32)}
# {'predictions': array([3038.6006], dtype=float32)}
# {'predictions': array([1924.848], dtype=float32)}
# {'predictions': array([1991.7943], dtype=float32)}
# {'predictions': array([1430.9713], dtype=float32)}
# {'predictions': array([1705.9061], dtype=float32)}
# {'predictions': array([1733.5667], dtype=float32)}
# {'predictions': array([3211.3574], dtype=float32)}
# {'predictions': array([1443.5874], dtype=float32)}
# {'predictions': array([1758.8177], dtype=float32)}
# {'predictions': array([1020.63324], dtype=float32)}
# {'predictions': array([1853.8953], dtype=float32)}
# {'predictions': array([1905.5961], dtype=float32)}
# {'predictions': array([2163.6487], dtype=float32)}
# {'predictions': array([1665.5453], dtype=float32)}
# {'predictions': array([1647.4525], dtype=float32)}
# {'predictions': array([1198.8134], dtype=float32)}
